# %%
import Bio #package
import Bio.PDB.parse_pdb_header #method
dirpath = '/Volumes/Kevin_SB/final_PDBs_2'#defining the directory location as a string variable
import os #package
directory = os.fsencode(dirpath) #method to encode the specified filename 

import pandas as pd
pdbfilenames = [] #creating an empty list that will be filled by the for loop. list of names in the directory

for file in os.listdir(directory): #looping through the files in the specified path
    filename = os.fsdecode(file)
    if filename.endswith(".ent"): #selecting files that are .pdd
        pdbfilenames.append(filename)

pdbfilenames #outputting the generated list
# Out:
# ['pdb1a0c.ent',
#  'pdb1a0d.ent',
#  'pdb1a0e.ent',
#  'pdb1a31.ent',
#  'pdb1a33.ent',
#  'pdb1a35.ent',
#  'pdb1a36.ent',
#  'pdb1a41.ent',
#  'pdb1a58.ent',
#  'pdb1a7x.ent',
#  'pdb1a9y.ent',
#  'pdb1a9z.ent',
#  'pdb1ab4.ent',
#  'pdb1ag1.ent',
#  'pdb1aj6.ent',
#  'pdb1ak4.ent',
#  'pdb1am2.ent',
#  'pdb1amk.ent',
#  'pdb1amu.ent',
#  'pdb1aon.ent',
#  'pdb1aw1.ent',
#  'pdb1aw2.ent',
#  'pdb1awq.ent',
#  'pdb1awr.ent',
#  'pdb1aws.ent',
#  'pdb1awt.ent',
#  'pdb1awu.ent',
#  'pdb1awv.ent',
#  'pdb1b0z.ent',
#  'pdb1b4v.ent',
#  'pdb1b6c.ent',
#  'pdb1b73.ent',
#  'pdb1b74.ent',
#  'pdb1b8s.ent',
#  'pdb1b9b.ent',
#  'pdb1b9l.ent',
#  'pdb1bck.ent',
#  'pdb1bd0.ent',
#  'pdb1bgw.ent',
#  'pdb1bhw.ent',
#  'pdb1bjp.ent',
#  'pdb1bjt.ent',
#  'pdb1bkf.ent',
#  'pdb1bkh.ent',
#  'pdb1bl4.ent',
#  'pdb1bq3.ent',
#  'pdb1bq4.ent',
#  'pdb1btm.ent',
#  'pdb1bwz.ent',
#  'pdb1bxb.ent',
#  'pdb1bxc.ent',
#  'pdb1c47.ent',
#  'pdb1c4g.ent',
#  'pdb1c5f.ent',
#  'pdb1c7h.ent',
#  'pdb1c7q.ent',
#  'pdb1c7r.ent',
#  'pdb1c9h.ent',
#  'pdb1ca7.ent',
#  'pdb1cb7.ent',
#  'pdb1cbo.ent',
#  'pdb1cc2.ent',
#  'pdb1ccw.ent',
#  'pdb1cgq.ent',
#  'pdb1ci1.ent',
#  'pdb1clk.ent',
#  'pdb1com.ent',
#  'pdb1coy.ent',
#  'pdb1cqs.ent',
#  'pdb1csm.ent',
#  'pdb1cwa.ent',
#  'pdb1cwb.ent',
#  'pdb1cwc.ent',
#  'pdb1cwf.ent',
#  'pdb1cwh.ent',
#  'pdb1cwi.ent',
#  'pdb1cwj.ent',
#  'pdb1cwk.ent',
#  'pdb1cwl.ent',
#  'pdb1cwm.ent',
#  'pdb1cwo.ent',
#  'pdb1cy0.ent',
#  'pdb1cy1.ent',
#  'pdb1cy2.ent',
#  'pdb1cy4.ent',
#  'pdb1cy6.ent',
#  'pdb1cy7.ent',
#  'pdb1cy8.ent',
#  'pdb1cy9.ent',
#  'pdb1cyn.ent',
#  'pdb1cyy.ent',
#  'pdb1d3y.ent',
#  'pdb1d6m.ent',
#  'pdb1d6o.ent',
#  'pdb1d7a.ent',
#  'pdb1d7h.ent',
#  'pdb1d7i.ent',
#  'pdb1d7j.ent',
#  'pdb1d8w.ent',
#  'pdb1dbf.ent',
#  'pdb1dci.ent',
#  'pdb1de5.ent',
#  'pdb1de6.ent',
#  'pdb1dhn.ent',
#  'pdb1did.ent',
#  'pdb1die.ent',
#  'pdb1dj0.ent',
#  'pdb1dk7.ent',
#  'pdb1dkd.ent',
#  'pdb1dkw.ent',
#  'pdb1dl3.ent',
#  'pdb1dmm.ent',
#  'pdb1dmn.ent',
#  'pdb1dmq.ent',
#  'pdb1dqr.ent',
#  'pdb1dtn.ent',
#  'pdb1dub.ent',
#  'pdb1dxi.ent',
#  'pdb1dyw.ent',
#  'pdb1dzr.ent',
#  'pdb1dzt.ent',
#  'pdb1e1c.ent',
#  'pdb1e3b.ent',
#  'pdb1e3r.ent',
#  'pdb1e3v.ent',
#  'pdb1e58.ent',
#  'pdb1e59.ent',
#  'pdb1e6b.ent',
#  'pdb1e6u.ent',
#  'pdb1e7q.ent',
#  'pdb1e7r.ent',
#  'pdb1e7s.ent',
#  'pdb1e8k.ent',
#  'pdb1e97.ent',
#  'pdb1ea2.ent',
#  'pdb1ecl.ent',
#  'pdb1ecm.ent',
#  'pdb1eej.ent',
#  'pdb1ei1.ent',
#  'pdb1ej9.ent',
#  'pdb1ejf.ent',
#  'pdb1ejj.ent',
#  'pdb1ek5.ent',
#  'pdb1ek6.ent',
#  'pdb1ep0.ent',
#  'pdb1epv.ent',
#  'pdb1epz.ent',
#  'pdb1eq2.ent',
#  'pdb1eqj.ent',
#  'pdb1ev4.ent',
#  'pdb1ev9.ent',
#  'pdb1ey3.ent',
#  'pdb1eym.ent',
#  'pdb1eyp.ent',
#  'pdb1eyq.ent',
#  'pdb1f2v.ent',
#  'pdb1f3a.ent',
#  'pdb1f3b.ent',
#  'pdb1f6d.ent',
#  'pdb1f8a.ent',
#  'pdb1f9c.ent',
#  'pdb1fap.ent',
#  'pdb1fd9.ent',
#  'pdb1fgl.ent',
#  'pdb1fim.ent',
#  'pdb1fkb.ent',
#  'pdb1fkd.ent',
#  'pdb1fkf.ent',
#  'pdb1fkg.ent',
#  'pdb1fkh.ent',
#  'pdb1fki.ent',
#  'pdb1fkj.ent',
#  'pdb1fkk.ent',
#  'pdb1fkl.ent',
#  'pdb1fm7.ent',
#  'pdb1fm8.ent',
#  'pdb1fnj.ent',
#  'pdb1fnk.ent',
#  'pdb1fp3.ent',
#  'pdb1ftx.ent',
#  'pdb1fui.ent',
#  'pdb1fw1.ent',
#  'pdb1fy9.ent',
#  'pdb1fya.ent',
#  'pdb1g0t.ent',
#  'pdb1g57.ent',
#  'pdb1g58.ent',
#  'pdb1g98.ent',
#  'pdb1gcz.ent',
#  'pdb1gd0.ent',
#  'pdb1gif.ent',
#  'pdb1gku.ent',
#  'pdb1gl9.ent',
#  'pdb1gqz.ent',
#  'pdb1gr0.ent',
#  'pdb1gr5.ent',
#  'pdb1grl.ent',
#  'pdb1gru.ent',
#  'pdb1gs3.ent',
#  'pdb1gsd.ent',
#  'pdb1gse.ent',
#  'pdb1gsf.ent',
#  'pdb1gsz.ent',
#  'pdb1gtt.ent',
#  'pdb1guh.ent',
#  'pdb1gw9.ent',
#  'pdb1gy8.ent',
#  'pdb1gyj.ent',
#  'pdb1gyx.ent',
#  'pdb1gyy.ent',
#  'pdb1gzd.ent',
#  'pdb1gzv.ent',
#  'pdb1h0p.ent',
#  'pdb1h1y.ent',
#  'pdb1h1z.ent',
#  'pdb1h35.ent',
#  'pdb1h36.ent',
#  'pdb1h37.ent',
#  'pdb1h39.ent',
#  'pdb1h3a.ent',
#  'pdb1h3b.ent',
#  'pdb1h3c.ent',
#  'pdb1hfo.ent',
#  'pdb1hg3.ent',
#  'pdb1hm5.ent',
#  'pdb1hno.ent',
#  'pdb1hnu.ent',
#  'pdb1hox.ent',
#  'pdb1hti.ent',
#  'pdb1hx3.ent',
#  'pdb1hzj.ent',
#  'pdb1hzt.ent',
#  'pdb1i1h.ent',
#  'pdb1i3k.ent',
#  'pdb1i3l.ent',
#  'pdb1i3m.ent',
#  'pdb1i3n.ent',
#  'pdb1i45.ent',
#  'pdb1i60.ent',
#  'pdb1i6n.ent',
#  'pdb1i7d.ent',
#  'pdb1i7o.ent',
#  'pdb1i8t.ent',
#  'pdb1i9a.ent',
#  'pdb1i9c.ent',
#  'pdb1iat.ent',
#  'pdb1if2.ent',
#  'pdb1ihg.ent',
#  'pdb1iig.ent',
#  'pdb1iih.ent',
#  'pdb1iip.ent',
#  'pdb1ijh.ent',
#  'pdb1iok.ent',
#  'pdb1iri.ent',
#  'pdb1ist.ent',
#  'pdb1iu9.ent',
#  'pdb1iv8.ent',
#  'pdb1iyh.ent',
#  'pdb1iyi.ent',
#  'pdb1j2a.ent',
#  'pdb1j3p.ent',
#  'pdb1j3q.ent',
#  'pdb1j3r.ent',
#  'pdb1j4h.ent',
#  'pdb1j4i.ent',
#  'pdb1j4r.ent',
#  'pdb1j5s.ent',
#  'pdb1jc4.ent',
#  'pdb1jc5.ent',
#  'pdb1jcm.ent',
#  'pdb1jdi.ent',
#  'pdb1jdy.ent',
#  'pdb1jeo.ent',
#  'pdb1jep.ent',
#  'pdb1jfl.ent',
#  'pdb1jiq.ent',
#  'pdb1jkf.ent',
#  'pdb1jki.ent',
#  'pdb1jlh.ent',
#  'pdb1jof.ent',
#  'pdb1jon.ent',
#  'pdb1jov.ent',
#  'pdb1jpd.ent',
#  'pdb1jpm.ent',
#  'pdb1jvw.ent',
#  'pdb1jx0.ent',
#  'pdb1jx1.ent',
#  'pdb1jzt.ent',
#  'pdb1k0w.ent',
#  'pdb1k2y.ent',
#  'pdb1k35.ent',
#  'pdb1k39.ent',
#  'pdb1k3l.ent',
#  'pdb1k3o.ent',
#  'pdb1k3y.ent',
#  'pdb1k41.ent',
#  'pdb1k49.ent',
#  'pdb1k4i.ent',
#  'pdb1k4l.ent',
#  'pdb1k4o.ent',
#  'pdb1k4p.ent',
#  'pdb1k4s.ent',
#  'pdb1k4t.ent',
#  'pdb1k77.ent',
#  'pdb1k8w.ent',
#  'pdb1kfi.ent',
#  'pdb1kfq.ent',
#  'pdb1kid.ent',
#  'pdb1kij.ent',
#  'pdb1koj.ent',
#  'pdb1kp8.ent',
#  'pdb1ks2.ent',
#  'pdb1ksk.ent',
#  'pdb1ksl.ent',
#  'pdb1ksv.ent',
#  'pdb1kt0.ent',
#  'pdb1kt1.ent',
#  'pdb1kv5.ent',
#  'pdb1kvq.ent',
#  'pdb1kvr.ent',
#  'pdb1kvs.ent',
#  'pdb1kvt.ent',
#  'pdb1kvu.ent',
#  'pdb1kzn.ent',
#  'pdb1l6f.ent',
#  'pdb1l6g.ent',
#  'pdb1l7j.ent',
#  'pdb1l7k.ent',
#  'pdb1la1.ent',
#  'pdb1la2.ent',
#  'pdb1lbm.ent',
#  'pdb1ljt.ent',
#  'pdb1lk5.ent',
#  'pdb1lk7.ent',
#  'pdb1lkz.ent',
#  'pdb1lop.ent',
#  'pdb1lpq.ent',
#  'pdb1lrj.ent',
#  'pdb1lrk.ent',
#  'pdb1lrl.ent',
#  'pdb1lur.ent',
#  'pdb1lvh.ent',
#  'pdb1lxt.ent',
#  'pdb1lyx.ent',
#  'pdb1lzo.ent',
#  'pdb1m0s.ent',
#  'pdb1m1b.ent',
#  'pdb1m3s.ent',
#  'pdb1m53.ent',
#  'pdb1m5y.ent',
#  'pdb1m63.ent',
#  'pdb1m6j.ent',
#  'pdb1m7o.ent',
#  'pdb1m7p.ent',
#  'pdb1m9c.ent',
#  'pdb1m9d.ent',
#  'pdb1m9e.ent',
#  'pdb1m9f.ent',
#  'pdb1m9x.ent',
#  'pdb1m9y.ent',
#  'pdb1mdl.ent',
#  'pdb1mdr.ent',
#  'pdb1mf8.ent',
#  'pdb1mff.ent',
#  'pdb1mfi.ent',
#  'pdb1mif.ent',
#  'pdb1mik.ent',
#  'pdb1mj3.ent',
#  'pdb1mka.ent',
#  'pdb1mkb.ent',
#  'pdb1ml1.ent',
#  'pdb1mli.ent',
#  'pdb1mmu.ent',
#  'pdb1mmx.ent',
#  'pdb1mmy.ent',
#  'pdb1mmz.ent',
#  'pdb1mn0.ent',
#  'pdb1mnf.ent',
#  'pdb1mns.ent',
#  'pdb1mnz.ent',
#  'pdb1mo0.ent',
#  'pdb1mra.ent',
#  'pdb1mss.ent',
#  'pdb1mu5.ent',
#  'pdb1muc.ent',
#  'pdb1muw.ent',
#  'pdb1mw8.ent',
#  'pdb1mw9.ent',
#  'pdb1mx0.ent',
#  'pdb1mxt.ent',
#  'pdb1mzw.ent',
#  'pdb1n1a.ent',
#  'pdb1n1b.ent',
#  'pdb1n1p.ent',
#  'pdb1n1z.ent',
#  'pdb1n20.ent',
#  'pdb1n21.ent',
#  'pdb1n22.ent',
#  'pdb1n23.ent',
#  'pdb1n24.ent',
#  'pdb1n4u.ent',
#  'pdb1n4v.ent',
#  'pdb1n4w.ent',
#  'pdb1n55.ent',
#  'pdb1n8t.ent',
#  'pdb1nah.ent',
#  'pdb1nai.ent',
#  'pdb1nbu.ent',
#  'pdb1ney.ent',
#  'pdb1nf0.ent',
#  'pdb1nfs.ent',
#  'pdb1nfz.ent',
#  'pdb1nh3.ent',
#  'pdb1niu.ent',
#  'pdb1nmk.ent',
#  'pdb1nn4.ent',
#  'pdb1ns0.ent',
#  'pdb1ns2.ent',
#  'pdb1ns4.ent',
#  'pdb1ns7.ent',
#  'pdb1ns8.ent',
#  'pdb1nsg.ent',
#  'pdb1nsj.ent',
#  'pdb1nsm.ent',
#  'pdb1nsr.ent',
#  'pdb1nss.ent',
#  'pdb1nsu.ent',
#  'pdb1nsv.ent',
#  'pdb1nsx.ent',
#  'pdb1nsz.ent',
#  'pdb1nu5.ent',
#  'pdb1nuh.ent',
#  'pdb1nxm.ent',
#  'pdb1nyw.ent',
#  'pdb1nzc.ent',
#  'pdb1o03.ent',
#  'pdb1o08.ent',
#  'pdb1o1h.ent',
#  'pdb1o1x.ent',
#  'pdb1o4v.ent',
#  'pdb1o5x.ent',
#  'pdb1o6c.ent',
#  'pdb1o6h.ent',
#  'pdb1o6q.ent',
#  'pdb1o6r.ent',
#  'pdb1o79.ent',
#  'pdb1o8b.ent',
#  'pdb1o98.ent',
#  'pdb1o99.ent',
#  'pdb1oad.ent',
#  'pdb1ocv.ent',
#  'pdb1ode.ent',
#  'pdb1oel.ent',
#  'pdb1ogc.ent',
#  'pdb1ogd.ent',
#  'pdb1oge.ent',
#  'pdb1ogf.ent',
#  'pdb1ogx.ent',
#  'pdb1ogz.ent',
#  'pdb1oh0.ent',
#  'pdb1oho.ent',
#  'pdb1ohp.ent',
#  'pdb1ohs.ent',
#  'pdb1ois.ent',
#  'pdb1oms.ent',
#  'pdb1opy.ent',
#  'pdb1orr.ent',
#  'pdb1otf.ent',
#  'pdb1otg.ent',
#  'pdb1ou0.ent',
#  'pdb1ow2.ent',
#  'pdb1p0k.ent',
#  'pdb1p0n.ent',
#  'pdb1p1f.ent',
#  'pdb1p1g.ent',
#  'pdb1p1h.ent',
#  'pdb1p1i.ent',
#  'pdb1p1j.ent',
#  'pdb1p1k.ent',
#  'pdb1p4d.ent',
#  'pdb1p5d.ent',
#  'pdb1p5g.ent',
#  'pdb1p5q.ent',
#  'pdb1p9y.ent',
#  'pdb1pbk.ent',
#  'pdb1pcj.ent',
#  'pdb1pcm.ent',
#  'pdb1pcq.ent',
#  'pdb1pd2.ent',
#  'pdb1pf9.ent',
#  'pdb1pgi.ent',
#  'pdb1pii.ent',
#  'pdb1pin.ent',
#  'pdb1pjh.ent',
#  'pdb1pkw.ent',
#  'pdb1pkz.ent',
#  'pdb1pl1.ent',
#  'pdb1pl2.ent',
#  'pdb1pm7.ent',
#  'pdb1pmi.ent',
#  'pdb1ppv.ent',
#  'pdb1ppw.ent',
#  'pdb1prz.ent',
#  'pdb1pvf.ent',
#  'pdb1pvg.ent',
#  'pdb1pvw.ent',
#  'pdb1pvy.ent',
#  'pdb1pym.ent',
#  'pdb1q1c.ent',
#  'pdb1q3h.ent',
#  'pdb1q50.ent',
#  'pdb1q54.ent',
#  'pdb1q5n.ent',
#  'pdb1q6h.ent',
#  'pdb1q6i.ent',
#  'pdb1q6u.ent',
#  'pdb1qcz.ent',
#  'pdb1qds.ent',
#  'pdb1qhf.ent',
#  'pdb1qjg.ent',
#  'pdb1qng.ent',
#  'pdb1qnh.ent',
#  'pdb1qo2.ent',
#  'pdb1qoi.ent',
#  'pdb1qpf.ent',
#  'pdb1qpl.ent',
#  'pdb1qt1.ent',
#  'pdb1qwr.ent',
#  'pdb1qxj.ent',
#  'pdb1qxr.ent',
#  'pdb1qy4.ent',
#  'pdb1qy9.ent',
#  'pdb1qya.ent',
#  'pdb1qyu.ent',
#  'pdb1qz2.ent',
#  'pdb1qzr.ent',
#  'pdb1r0m.ent',
#  'pdb1r0w.ent',
#  'pdb1r0x.ent',
#  'pdb1r0y.ent',
#  'pdb1r0z.ent',
#  'pdb1r10.ent',
#  'pdb1r2r.ent',
#  'pdb1r2s.ent',
#  'pdb1r2t.ent',
#  'pdb1r3e.ent',
#  'pdb1r3f.ent',
#  'pdb1r49.ent',
#  'pdb1r67.ent',
#  'pdb1r9h.ent',
#  'pdb1rcq.ent',
#  'pdb1re5.ent',
#  'pdb1req.ent',
#  'pdb1rii.ent',
#  'pdb1rm0.ent',
#  'pdb1rmh.ent',
#  'pdb1rpx.ent',
#  'pdb1rr8.ent',
#  'pdb1rri.ent',
#  'pdb1rrj.ent',
#  'pdb1rrw.ent',
#  'pdb1rry.ent',
#  'pdb1rs2.ent',
#  'pdb1rs4.ent',
#  'pdb1rsd.ent',
#  'pdb1rsi.ent',
#  'pdb1rtv.ent',
#  'pdb1s0y.ent',
#  'pdb1s14.ent',
#  'pdb1s16.ent',
#  'pdb1s2t.ent',
#  'pdb1s2u.ent',
#  'pdb1s2v.ent',
#  'pdb1s2w.ent',
#  'pdb1s5m.ent',
#  'pdb1s5n.ent',
#  'pdb1sb7.ent',
#  'pdb1sb8.ent',
#  'pdb1sb9.ent',
#  'pdb1sc7.ent',
#  'pdb1sdj.ent',
#  'pdb1seu.ent',
#  'pdb1sft.ent',
#  'pdb1sg4.ent',
#  'pdb1sgv.ent',
#  'pdb1si7.ent',
#  'pdb1sja.ent',
#  'pdb1sjb.ent',
#  'pdb1sjc.ent',
#  'pdb1sjd.ent',
#  'pdb1sjp.ent',
#  'pdb1sjw.ent',
#  'pdb1snn.ent',
#  'pdb1snz.ent',
#  'pdb1so0.ent',
#  'pdb1spq.ent',
#  'pdb1sq7.ent',
#  'pdb1sqc.ent',
#  'pdb1srv.ent',
#  'pdb1ss8.ent',
#  'pdb1ssd.ent',
#  'pdb1ssg.ent',
#  'pdb1su5.ent',
#  'pdb1suu.ent',
#  'pdb1sux.ent',
#  'pdb1svt.ent',
#  'pdb1sw0.ent',
#  'pdb1sw3.ent',
#  'pdb1sw7.ent',
#  'pdb1sx3.ent',
#  'pdb1sx4.ent',
#  'pdb1szw.ent',
#  'pdb1t10.ent',
#  'pdb1t11.ent',
#  'pdb1t3b.ent',
#  'pdb1t5o.ent',
#  'pdb1t6k.ent',
#  'pdb1t8i.ent',
#  'pdb1t8p.ent',
#  'pdb1t9k.ent',
#  'pdb1tcd.ent',
#  'pdb1tco.ent',
#  'pdb1tim.ent',
#  'pdb1tjd.ent',
#  'pdb1tk9.ent',
#  'pdb1tkk.ent',
#  'pdb1tks.ent',
#  'pdb1tku.ent',
#  'pdb1tl8.ent',
#  'pdb1tm0.ent',
#  'pdb1tmh.ent',
#  'pdb1tpb.ent',
#  'pdb1tpc.ent',
#  'pdb1tpd.ent',
#  'pdb1tpe.ent',
#  'pdb1tpf.ent',
#  'pdb1tph.ent',
#  'pdb1tpu.ent',
#  'pdb1tpv.ent',
#  'pdb1tpw.ent',
#  'pdb1tqj.ent',
#  'pdb1tqx.ent',
#  'pdb1trd.ent',
#  'pdb1tre.ent',
#  'pdb1tri.ent',
#  'pdb1tsi.ent',
#  'pdb1tti.ent',
#  'pdb1ttj.ent',
#  'pdb1tzb.ent',
#  'pdb1tzc.ent',
#  'pdb1u0e.ent',
#  'pdb1u0f.ent',
#  'pdb1u0g.ent',
#  'pdb1u11.ent',
#  'pdb1u1v.ent',
#  'pdb1u1w.ent',
#  'pdb1u1x.ent',
#  'pdb1u68.ent',
#  'pdb1u79.ent',
#  'pdb1u8v.ent',
#  'pdb1uda.ent',
#  'pdb1udb.ent',
#  'pdb1udc.ent',
#  'pdb1ufy.ent',
#  'pdb1ui9.ent',
#  'pdb1uiz.ent',
#  'pdb1uj4.ent',
#  'pdb1uj5.ent',
#  'pdb1uj6.ent',
#  'pdb1ump.ent',
#  'pdb1upi.ent',
#  'pdb1usb.ent',
#  'pdb1usl.ent',
#  'pdb1v0j.ent',
#  'pdb1v37.ent',
#  'pdb1v40.ent',
#  'pdb1v4v.ent',
#  'pdb1v5x.ent',
#  'pdb1v71.ent',
#  'pdb1v7q.ent',
#  'pdb1v9c.ent',
#  'pdb1v9f.ent',
#  'pdb1v9k.ent',
#  'pdb1v9t.ent',
#  'pdb1vai.ent',
#  'pdb1vbs.ent',
#  'pdb1vbt.ent',
#  'pdb1vcc.ent',
#  'pdb1vcf.ent',
#  'pdb1vcg.ent',
#  'pdb1vdn.ent',
#  'pdb1vfh.ent',
#  'pdb1vfs.ent',
#  'pdb1vft.ent',
#  'pdb1vga.ent',
#  'pdb1vgv.ent',
#  'pdb1vio.ent',
#  'pdb1viv.ent',
#  'pdb1vkl.ent',
#  'pdb1vko.ent',
#  'pdb1vky.ent',
#  'pdb1vpe.ent',
#  'pdb1vs3.ent',
#  'pdb1vzw.ent',
#  'pdb1vzz.ent',
#  'pdb1w00.ent',
#  'pdb1w01.ent',
#  'pdb1w02.ent',
#  'pdb1w0m.ent',
#  'pdb1w26.ent',
#  'pdb1w2b.ent',
#  'pdb1w2w.ent',
#  'pdb1w61.ent',
#  'pdb1w62.ent',
#  'pdb1w6j.ent',
#  'pdb1w6k.ent',
#  'pdb1w6y.ent',
#  'pdb1w74.ent',
#  'pdb1w8l.ent',
#  'pdb1w8m.ent',
#  'pdb1w8v.ent',
#  'pdb1wam.ent',
#  'pdb1wdk.ent',
#  'pdb1wdl.ent',
#  'pdb1wdm.ent',
#  'pdb1wlt.ent',
#  'pdb1woa.ent',
#  'pdb1wob.ent',
#  'pdb1wp5.ent',
#  'pdb1wqa.ent',
#  'pdb1wtc.ent',
#  'pdb1wue.ent',
#  'pdb1wuf.ent',
#  'pdb1wyi.ent',
#  'pdb1wzo.ent',
#  'pdb1x74.ent',
#  'pdb1x75.ent',
#  'pdb1x7n.ent',
#  'pdb1x82.ent',
#  'pdb1x83.ent',
#  'pdb1x84.ent',
#  'pdb1x8d.ent',
#  'pdb1x8e.ent',
#  'pdb1x8m.ent',
#  'pdb1x92.ent',
#  'pdb1x94.ent',
#  'pdb1x9h.ent',
#  'pdb1x9i.ent',
#  'pdb1xck.ent',
#  'pdb1xel.ent',
#  'pdb1xf9.ent',
#  'pdb1xfa.ent',
#  'pdb1xfc.ent',
#  'pdb1xho.ent',
#  'pdb1xia.ent',
#  'pdb1xib.ent',
#  'pdb1xic.ent',
#  'pdb1xid.ent',
#  'pdb1xie.ent',
#  'pdb1xif.ent',
#  'pdb1xig.ent',
#  'pdb1xih.ent',
#  'pdb1xii.ent',
#  'pdb1xij.ent',
#  'pdb1xim.ent',
#  'pdb1xin.ent',
#  'pdb1xis.ent',
#  'pdb1xla.ent',
#  'pdb1xlb.ent',
#  'pdb1xlc.ent',
#  'pdb1xld.ent',
#  'pdb1xle.ent',
#  'pdb1xlf.ent',
#  'pdb1xlg.ent',
#  'pdb1xlh.ent',
#  'pdb1xli.ent',
#  'pdb1xlj.ent',
#  'pdb1xlk.ent',
#  'pdb1xll.ent',
#  'pdb1xlm.ent',
#  'pdb1xmi.ent',
#  'pdb1xmj.ent',
#  'pdb1xmp.ent',
#  'pdb1xo7.ent',
#  'pdb1xpi.ent',
#  'pdb1xpy.ent',
#  'pdb1xq7.ent',
#  'pdb1xq9.ent',
#  'pdb1xqk.ent',
#  'pdb1xql.ent',
#  'pdb1xrs.ent',
#  'pdb1xru.ent',
#  'pdb1xs2.ent',
#  'pdb1xtb.ent',
#  'pdb1xtz.ent',
#  'pdb1xua.ent',
#  'pdb1xub.ent',
#  'pdb1xwg.ent',
#  'pdb1xx4.ent',
#  'pdb1xya.ent',
#  'pdb1xyb.ent',
#  'pdb1xyc.ent',
#  'pdb1xyh.ent',
#  'pdb1xyl.ent',
#  'pdb1xym.ent',
#  'pdb1y0e.ent',
#  'pdb1y0o.ent',
#  'pdb1yad.ent',
#  'pdb1yat.ent',
#  'pdb1ybz.ent',
#  'pdb1ydk.ent',
#  'pdb1ydv.ent',
#  'pdb1yfk.ent',
#  'pdb1yga.ent',
#  'pdb1yjx.ent',
#  'pdb1ym5.ent',
#  'pdb1ynd.ent',
#  'pdb1ypi.ent',
#  'pdb1yw5.ent',
#  'pdb1ywk.ent',
#  'pdb1yxy.ent',
#  'pdb1yy3.ent',
#  'pdb1yya.ent',
#  'pdb1z2z.ent',
#  'pdb1z45.ent',
#  'pdb1z4n.ent',
#  'pdb1z4o.ent',
#  'pdb1z59.ent',
#  'pdb1z5a.ent',
#  'pdb1z5b.ent',
#  'pdb1z5c.ent',
#  'pdb1z81.ent',
#  'pdb1z8k.ent',
#  'pdb1z9h.ent',
#  'pdb1z9w.ent',
#  'pdb1zcj.ent',
#  'pdb1zcn.ent',
#  'pdb1ze1.ent',
#  'pdb1ze2.ent',
#  'pdb1zi0.ent',
#  'pdb1zja.ent',
#  'pdb1zjb.ent',
#  'pdb1zkc.ent',
#  'pdb1zkf.ent',
#  'pdb1zl3.ent',
#  'pdb1zmf.ent',
#  'pdb1zol.ent',
#  'pdb1zuw.ent',
#  'pdb1zvc.ent',
#  'pdb1zvt.ent',
#  'pdb1zvu.ent',
#  'pdb1zx5.ent',
#  'pdb1zxm.ent',
#  'pdb1zxn.ent',
#  'pdb1zzg.ent',
#  'pdb2a0i.ent',
#  'pdb2a0u.ent',
#  'pdb2a13.ent',
#  'pdb2a2n.ent',
#  'pdb2a5h.ent',
#  'pdb2a6p.ent',
#  'pdb2a9j.ent',
#  'pdb2aar.ent',
#  'pdb2ab4.ent',
#  'pdb2afa.ent',
#  'pdb2afr.ent',
#  'pdb2afv.ent',
#  'pdb2agk.ent',
#  'pdb2ajt.ent',
#  'pdb2alf.ent',
#  'pdb2amy.ent',
#  'pdb2ao2.ent',
#  'pdb2apo.ent',
#  'pdb2ate.ent',
#  'pdb2aus.ent',
#  'pdb2awg.ent',
#  'pdb2ax3.ent',
#  'pdb2azp.ent',
#  'pdb2b2k.ent',
#  'pdb2b5e.ent',
#  'pdb2b71.ent',
#  'pdb2b9s.ent',
#  'pdb2b9u.ent',
#  'pdb2bbo.ent',
#  'pdb2bbs.ent',
#  'pdb2bbt.ent',
#  'pdb2bes.ent',
#  'pdb2bet.ent',
#  'pdb2bi7.ent',
#  'pdb2bi8.ent',
#  'pdb2bit.ent',
#  'pdb2biu.ent',
#  'pdb2brj.ent',
#  'pdb2btm.ent',
#  'pdb2c0z.ent',
#  'pdb2c20.ent',
#  'pdb2c3b.ent',
#  'pdb2c54.ent',
#  'pdb2c59.ent',
#  'pdb2c5a.ent',
#  'pdb2c5e.ent',
#  'pdb2c7c.ent',
#  'pdb2c7d.ent',
#  'pdb2c7e.ent',
#  'pdb2cfb.ent',
#  'pdb2cfe.ent',
#  'pdb2cff.ent',
#  'pdb2cgt.ent',
#  'pdb2chr.ent',
#  'pdb2chs.ent',
#  'pdb2cht.ent',
#  'pdb2ciq.ent',
#  'pdb2cir.ent',
#  'pdb2cis.ent',
#  'pdb2ck1.ent',
#  'pdb2cmt.ent',
#  'pdb2cnb.ent',
#  'pdb2cpl.ent',
#  'pdb2csm.ent',
#  'pdb2cvd.ent',
#  'pdb2cvp.ent',
#  'pdb2cxn.ent',
#  'pdb2cxo.ent',
#  'pdb2cxp.ent',
#  'pdb2cxq.ent',
#  'pdb2cxr.ent',
#  'pdb2cxs.ent',
#  'pdb2cxt.ent',
#  'pdb2cxu.ent',
#  'pdb2cyh.ent',
#  'pdb2cz2.ent',
#  'pdb2cz3.ent',
#  'pdb2czt.ent',
#  'pdb2czu.ent',
#  'pdb2d3o.ent',
#  'pdb2d3t.ent',
#  'pdb2d8d.ent',
#  'pdb2d8e.ent',
#  'pdb2dfu.ent',
#  'pdb2dg2.ent',
#  'pdb2dg3.ent',
#  'pdb2dg4.ent',
#  'pdb2dg9.ent',
#  'pdb2dhn.ent',
#  'pdb2dho.ent',
#  'pdb2dio.ent',
#  'pdb2dka.ent',
#  'pdb2dkc.ent',
#  'pdb2dkd.ent',
#  'pdb2dp3.ent',
#  'pdb2dub.ent',
#  'pdb2dwu.ent',
#  'pdb2dx7.ent',
#  'pdb2dy3.ent',
#  'pdb2e7u.ent',
#  'pdb2epj.ent',
#  'pdb2eq5.ent',
#  'pdb2esl.ent',
#  'pdb2eu1.ent',
#  'pdb2eua.ent',
#  'pdb2ey4.ent',
#  'pdb2f21.ent',
#  'pdb2f4e.ent',
#  'pdb2f6l.ent',
#  'pdb2f6q.ent',
#  'pdb2f7l.ent',
#  'pdb2f8m.ent',
#  'pdb2f90.ent',
#  'pdb2f98.ent',
#  'pdb2f99.ent',
#  'pdb2fap.ent',
#  'pdb2fbn.ent',
#  'pdb2fel.ent',
#  'pdb2fen.ent',
#  'pdb2fke.ent',
#  'pdb2fkf.ent',
#  'pdb2fkm.ent',
#  'pdb2fkp.ent',
#  'pdb2fli.ent',
#  'pdb2fm7.ent',
#  'pdb2fp1.ent',
#  'pdb2fp2.ent',
#  'pdb2fr2.ent',
#  'pdb2fu0.ent',
#  'pdb2fuc.ent',
#  'pdb2fue.ent',
#  'pdb2fuv.ent',
#  'pdb2fw1.ent',
#  'pdb2fw6.ent',
#  'pdb2fw7.ent',
#  'pdb2fw8.ent',
#  'pdb2fw9.ent',
#  'pdb2fwa.ent',
#  'pdb2fwb.ent',
#  'pdb2fwi.ent',
#  'pdb2fwj.ent',
#  'pdb2fwp.ent',
#  'pdb2fwv.ent',
#  'pdb2g04.ent',
#  'pdb2g4j.ent',
#  ...]

# %%
header_list =[] #empty list that will be ammended with dictionaries

#creates a dictionary for items in the PDB header, named header
def read_pdb_header (input_file):
    headerdetails = Bio.PDB.parse_pdb_header(input_file) #parsing PDB file, saving as "headerdetails"
    header_list.append(headerdetails) #adding those "headerdetails" to the header_list dictionary

   
for i in range(len(pdbfilenames)-1): #iteratively calling the function
    with open("/Volumes/Kevin_SB/final_PDBs_2/"+pdbfilenames[i], "rb"): #iteratively pointing to the files
        read_pdb_header('/Volumes/Kevin_SB/final_PDBs_2/'+pdbfilenames[i]) #calling the function for the file selected by above step

        
import pandas as pd #package
df = pd.DataFrame([header_list[0]]) #creating a dataframe, starting with the first entry of the output

value = 1 #setting a counting variable that will increase with each run of the for loop
for w in header_list: #moving through each item in the header_list 
    df.loc[value] = w #assigning each value from header_list to the dataframe
    value = value +1 #increasing counting variable, to keep for loop moving

#block to pull out data frames by technique and time interval from the big table, writes a list for plotting
#select Xray, time interval1
day1 = '1976-01-01'
day2 = '1989-12-31'
mask1 = (df['deposition_date'] > day1) & (df['deposition_date'] <= day2) & (df['structure_method'] == 'x-ray diffraction')
X76_89 = df.loc[mask1]

#select Xray, time interval2
day3 = '1990-01-01'
day4 = '1999-12-31'
mask2 = (df['deposition_date'] > day3) & (df['deposition_date'] <= day4) & (df['structure_method'] == 'x-ray diffraction')
X90_99 = df.loc[mask2]

#select Xray, time interval3
day5 = '2000-01-01'
day6 = '2009-12-31'
mask3 = (df['deposition_date'] > day5) & (df['deposition_date'] <= day6) & (df['structure_method'] == 'x-ray diffraction')
X00_09 = df.loc[mask3]

#select Xray, time interval4
day7 = '2010-01-01'
day8 = '2014-12-31'
mask4 = (df['deposition_date'] > day7) & (df['deposition_date'] <= day8) & (df['structure_method'] == 'x-ray diffraction')
X10_14 = df.loc[mask4]

#select Xray, time interval5
day9 = '2015-01-01'
day10 = '2022-12-31'
mask5 = (df['deposition_date'] > day9) & (df['deposition_date'] <= day10) & (df['structure_method'] == 'x-ray diffraction')
X15_22 = df.loc[mask5]

#select EM, time interval1
day_1 = '1990-01-01'
day_2 = '2009-12-31'
mask_1 = (df['deposition_date'] > day_1) & (df['deposition_date'] <= day_2) & (df['structure_method'] == 'electron microscopy')
E90_09 = df.loc[mask_1]

#select EM, time interval2
day_3 = '2010-01-01'
day_4 = '2014-12-31'
mask_2 = (df['deposition_date'] > day_3) & (df['deposition_date'] <= day_4) & (df['structure_method'] == 'electron microscopy')
E10_14 = df.loc[mask_2]

#select EM, time interval3
day_5 = '2015-01-01'
day_6 = '2022-12-31'
mask_3 = (df['deposition_date'] > day_5) & (df['deposition_date'] <= day_6) & (df['structure_method'] == 'electron microscopy')
E15_22 = df.loc[mask_3]

#write a list with each of the data frames we want to plot
toplot = [X76_89, X90_99, X00_09, X10_14, X15_22, E90_09, E10_14, E15_22]

import matplotlib.pyplot as plt #package
import numpy as np #package
import pandas as pd #package

#plot a histogram for each dataframe by looping over the list with an enumerator (x) to help with naming the plots. X runs from 0 to 7.
for x,j in enumerate(toplot):
    
    names = ["Xray_1976-89", "Xray_1990-99", "Xray_2000-2009", "Xray_2010-2014", "Xray_2015-2022", "EM_1990-2009", "EM_2010-2014", "EM_2015-2022"]
    
    #plotting function
    j.hist(column='resolution', grid=False, figsize=(14,8))
    
    # save figure
    plt.savefig( names[x] + ".png", dpi=350)
    
    # Show Plot
    plt.show()

# %%
df
# Out:
#                                                    name  \
# 0     xylose isomerase from thermoanaerobacterium th...
# 1     xylose isomerase from thermoanaerobacterium th...
# 2     xylose isomerase from bacillus stearothermophilus
# 3          xylose isomerase from thermotoga neapolitana
# 4     human reconstituted dna topoisomerase i in cov...
# ...                                                 ...
# 4019  crystal structure of the gdp-d-glycero-4-keto-...
# 4020                         triose phosphate isomerase
# 4021  x-ray analysis of d-xylose isomerase at 1.9 an...
# 4022  protein engineering of xylose (glucose) isomer...
# 4023  x-ray analysis of d-xylose isomerase at 1.9 an...
#
#                                                    head idcode  \
# 0                                        ketolisomerase   1A0C
# 1                                        ketolisomerase   1A0C
# 2                                        ketolisomerase   1A0D
# 3                                        ketolisomerase   1A0E
# 4                                         isomerase/dna   1A31
# ...                                                 ...    ...
# 4019                                          isomerase   8DCO
# 4020                                          isomerase   8TIM
# 4021  isomerase(intramolecular oxidoreductase)11-oct...   8XIA
# 4022  isomerase(intramolecular oxidoreductase)01-apr...   8XIM
# 4023  isomerase(intramolecular oxidoreductase)11-oct...   9XIA
#
#      deposition_date release_date   structure_method  resolution  \
# 0         1997-11-28   1998-06-03  x-ray diffraction         2.5
# 1         1997-11-28   1998-06-03  x-ray diffraction         2.5
# 2         1997-11-28   1998-06-03  x-ray diffraction         3.0
# 3         1997-11-28   1998-06-03  x-ray diffraction         2.7
# 4         1998-01-27   1998-08-28  x-ray diffraction         2.1
# ...              ...          ...                ...         ...
# 4019      2022-06-17   2022-06-29  x-ray diffraction         1.9
# 4020      1998-08-25   1999-02-16  x-ray diffraction         2.5
# 4021      1990-10-11   1991-10-15  x-ray diffraction         1.9
# 4022      1992-04-01   1993-07-15  x-ray diffraction         2.4
# 4023      1990-10-11   1991-10-15  x-ray diffraction         1.9
#
#                                     structure_reference  \
# 0     [l.f.lloyd,o.s.gallay,j.akins,j.g.zeikus cryst...
# 1     [l.f.lloyd,o.s.gallay,j.akins,j.g.zeikus cryst...
# 2     [l.wuxiang,k.jeyaseelan high level expression ...
# 3     [n.e.chayen,e.conti,c.vieille,j.g.zeikus cryst...
# 4                                                    []
# ...                                                 ...
# 4019                                                 []
# 4020  [m.l.chang,p.j.artymiuk,x.wu,s.hollan,a.lammi,...
# 4021  [k.henrick,d.m.blow,h.l.carrell,j.p.glusker co...
# 4022  [a.-m.lambeir,m.lauwereys,p.stanssens,n.t.mrab...
# 4023  [k.henrick,d.m.blow,h.l.carrell,j.p.glusker co...
#
#                                       journal_reference  \
# 0     o.gallay,r.chopra,e.conti,p.brick,r.jackson, b...
# 1     o.gallay,r.chopra,e.conti,p.brick,r.jackson, b...
# 2     o.gallay,r.chopra,e.conti,p.brick,r.jackson,b....
# 3     o.gallay,r.chopra,e.conti,p.brick,r.jackson,b....
# 4     m.r.redinbo,l.stewart,p.kuhn,j.j.champoux,w.g....
# ...                                                 ...
# 4019  j.b.thoden,d.f.xiang,m.k.ghosh,f.m.raushel,h.m...
# 4020  p.j.artymiuk,w.r.taylor,d.c.phillips triose ph...
# 4021  h.l.carrell,j.p.glusker,v.burger,f.manfre,d.tr...
# 4022  j.jenkins,j.janin,f.rey,m.chiadmi,h.van tilbeu...
# 4023  h.l.carrell,j.p.glusker,v.burger,f.manfre,d.tr...
#
#                                                  author  \
# 0              O.Gallay,R.Chopra,E.Conti,P.Brick,D.Blow
# 1              O.Gallay,R.Chopra,E.Conti,P.Brick,D.Blow
# 2              O.Gallay,R.Chopra,E.Conti,P.Brick,D.Blow
# 3              O.Gallay,R.Chopra,E.Conti,P.Brick,D.Blow
# 4     M.R.Redinbo,L.Stewart,P.Kuhn,J.J.Champoux,W.G....
# ...                                                 ...
# 4019  J.B.Thoden,D.F.Xiang,M.K.Ghosh,F.M.Raushel,H.M...
# 4020               P.J.Artymiuk,W.R.Taylor,D.C.Phillips
# 4021                            H.L.Carrell,J.P.Glusker
# 4022                                            J.Janin
# 4023                            H.L.Carrell,J.P.Glusker
#
#                                                compound  \
# 0     {'1': {'misc': '', 'molecule': 'xylose isomera...
# 1     {'1': {'misc': '', 'molecule': 'xylose isomera...
# 2     {'1': {'misc': '', 'molecule': 'xylose isomera...
# 3     {'1': {'misc': '', 'molecule': 'xylose isomera...
# 4     {'1': {'misc': '', 'molecule': 'dna (5'-d(*ap*...
# ...                                                 ...
# 4019  {'1': {'misc': '', 'molecule': 'gdp-d-glycero-...
# 4020  {'1': {'misc': '', 'molecule': 'triose phospha...
# 4021  {'1': {'misc': '', 'molecule': 'xylose isomera...
# 4022  {'1': {'misc': '', 'molecule': 'd-xylose isome...
# 4023  {'1': {'misc': '', 'molecule': 'xylose isomera...
#
#                                                  source  has_missing_residues  \
# 0     {'1': {'misc': '', 'organism_scientific': 'the...                  True
# 1     {'1': {'misc': '', 'organism_scientific': 'the...                  True
# 2     {'1': {'misc': '', 'organism_scientific': 'geo...                  True
# 3     {'1': {'misc': '', 'organism_scientific': 'the...                 False
# 4     {'1': {'misc': '', 'synthetic': 'yes'}, '2': {...                  True
# ...                                                 ...                   ...
# 4019  {'1': {'misc': '', 'organism_scientific': 'cam...                  True
# 4020  {'1': {'misc': '', 'organism_scientific': 'gal...                 False
# 4021  {'1': {'misc': '', 'organism_scientific': 'str...                  True
# 4022  {'1': {'misc': '', 'organism_scientific': 'act...                  True
# 4023  {'1': {'misc': '', 'organism_scientific': 'str...                  True
#
#                                        missing_residues  \
# 0     [{'model': None, 'res_name': 'GLU', 'chain': '...
# 1     [{'model': None, 'res_name': 'GLU', 'chain': '...
# 2     [{'model': None, 'res_name': 'ALA', 'chain': '...
# 3                                                    []
# 4     [{'model': None, 'res_name': 'LYS', 'chain': '...
# ...                                                 ...
# 4019  [{'model': None, 'res_name': 'GLY', 'chain': '...
# 4020                                                 []
# 4021  [{'model': None, 'res_name': 'GLY', 'chain': '...
# 4022  [{'model': None, 'res_name': 'SER', 'chain': '...
# 4023  [{'model': None, 'res_name': 'GLY', 'chain': '...
#
#                                                keywords  \
# 0     ketolisomerase, xylose metabolism, glucose-fru...
# 1     ketolisomerase, xylose metabolism, glucose-fru...
# 2     ketolisomerase, xylose metabolism, glucose-fru...
# 3     ketolisomerase, xylose metabolism, glucose-fru...
# 4     topoisomerase i/dna, dna, topoisomerase i, iso...
# ...                                                 ...
# 4019  3, 5-epimerase, campylobacter, capsular polysa...
# 4020  isomerase, glycolysis, gluconeogenesis, fatty ...
# 4021           isomerase(intramolecular oxidoreductase)
# 4022           isomerase(intramolecular oxidoreductase)
# 4023           isomerase(intramolecular oxidoreductase)
#
#                                                 journal
# 0     AUTH   O.GALLAY,R.CHOPRA,E.CONTI,P.BRICK,R.JAC...
# 1     AUTH   O.GALLAY,R.CHOPRA,E.CONTI,P.BRICK,R.JAC...
# 2     AUTH   O.GALLAY,R.CHOPRA,E.CONTI,P.BRICK,R.JAC...
# 3     AUTH   O.GALLAY,R.CHOPRA,E.CONTI,P.BRICK,R.JAC...
# 4     AUTH   M.R.REDINBO,L.STEWART,P.KUHN,J.J.CHAMPO...
# ...                                                 ...
# 4019  AUTH   J.B.THODEN,D.F.XIANG,M.K.GHOSH,F.M.RAUS...
# 4020  AUTH   P.J.ARTYMIUK,W.R.TAYLOR,D.C.PHILLIPSTIT...
# 4021  AUTH   H.L.CARRELL,J.P.GLUSKER,V.BURGER,F.MANF...
# 4022  AUTH   J.JENKINS,J.JANIN,F.REY,M.CHIADMI,H.VAN...
# 4023  AUTH   H.L.CARRELL,J.P.GLUSKER,V.BURGER,F.MANF...
#
# [4024 rows x 16 columns]
